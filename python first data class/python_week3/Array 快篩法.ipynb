# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
L = np.array([3,-2,4,-5,333,-555,-601])

# %%
L < 0
# Out:
# array([False,  True, False,  True, False,  True,  True])

# %%
L[0]
# Out:
# 3

# %%
L[2:4]
# Out:
# array([ 4, -5])

# %%
L[L<0]             #篩出要的數字
# Out:
# array([  -2,   -5, -555, -601])

# %%
x = np.linspace(-5,5,500)
y = np.sinc(x)

plt.plot(x,y)

# %%
plt.plot(x,y)
plt.plot(x[y>0],y[y>0] , 'o')
