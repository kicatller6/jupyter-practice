# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
L = [1,3,5,7,9]

# %%
plot(L)

# %%
G=[3,4,5,1,2]

# %%
L+G
# Out:
# [1, 3, 5, 7, 9, 3, 4, 5, 1, 2]

# %%
plot(L+G)

# %%
G=[1,3,5]

# %%
L-G
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-7bce8929534d> in <module>
# ----> 1 L-G
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
u='123456'

# %%
u[0:5:3]
# Out:
# '14'
